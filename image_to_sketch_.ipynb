# %%
import numpy as np
import pandas as pd

import cv2 as cv
from google.colab.patches import cv2_imshow #image display
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request

# %%
image= io.imread("image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x350 at 0x7F6A1B8628B0>

# %%
grey_filter=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# Out:
# <PIL.Image.Image image mode=L size=400x350 at 0x7F6A1B8C1580>

# %%
invert=cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=400x350 at 0x7F6A1B862C70>

# %%
blur=cv.GaussianBlur(invert,(21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=400x350 at 0x7F6A1B862FA0>

# %%
invertedblur=cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=400x350 at 0x7F6A32C13CA0>

# %%
sketch_filter=cv.divide(grey_filter,invertedblur,scale=255.0)
cv2_imshow(sketch_filter)
cv.imwrite("sketch.jpg",sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=400x350 at 0x7F6A1B8629D0>
# True
